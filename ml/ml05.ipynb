# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import xgboost as xgb
from datetime import datetime

# Load datasets
vessel_data = pd.read_csv('../ais_train.csv', sep='|')
schedule_data = pd.read_csv('../schedules_to_may_2024.csv', sep='|')
ports_data = pd.read_csv('../ports.csv', sep='|')  # Load ports data
vessels_info = pd.read_csv('../vessels.csv', sep='|')  # Load vessel specifications

# %%
print(schedule_data)
# Out:
#                         vesselId            shippingLineId  \
# 0       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 1       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 2       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 3       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 4       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# ...                          ...                       ...
# 136245  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136246  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136247  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136248  61e9f3a9b937134a3c4bfe01  61a8e672f9cba188601e84ab
# 136249  61e9f3a9b937134a3c4bfe01  61a8e672f9cba188601e84ab
#
#                   shippingLineName                arrivalDate  \
# 0       Wallenius Wilhelmsen Ocean  2023-10-02 00:00:00+00:00
# 1       Wallenius Wilhelmsen Ocean  2023-10-27 00:00:00+00:00
# 2       Wallenius Wilhelmsen Ocean  2023-10-19 00:00:00+00:00
# 3       Wallenius Wilhelmsen Ocean  2023-10-09 00:00:00+00:00
# 4       Wallenius Wilhelmsen Ocean  2023-09-25 00:00:00+00:00
# ...                            ...                        ...
# 136245            Hoegh Autoliners  2023-12-03 23:00:00+00:00
# 136246            Hoegh Autoliners  2023-11-14 23:00:00+00:00
# 136247            Hoegh Autoliners  2023-11-15 23:00:00+00:00
# 136248            Hoegh Autoliners  2023-08-28 01:00:00+00:00
# 136249            Hoegh Autoliners  2023-08-20 04:30:00+00:00
#
#                       sailingDate                           portName  \
# 0       2023-10-03 00:00:00+00:00                  Port of Brunswick
# 1       2023-10-27 00:00:00+00:00                Port of Southampton
# 2       2023-10-20 00:00:00+00:00                Port of Bremerhaven
# 3       2023-10-10 00:00:00+00:00                   Port of New York
# 4       2023-09-26 00:00:00+00:00  Manzanillo International Terminal
# ...                           ...                                ...
# 136245  2023-12-03 23:00:00+00:00               Port of Laem Chabang
# 136246  2023-11-14 23:00:00+00:00                         Port Zayed
# 136247  2023-11-15 23:00:00+00:00                                NaN
# 136248  2023-08-30 17:00:00+00:00             The Port of Wilmington
# 136249  2023-08-23 04:30:00+00:00                      Port Freeport
#
#                           portId  portLatitude  portLongitude
# 0       61d38499b7b7526e1adf3d54     31.140556     -81.496667
# 1       61d3832bb7b7526e1adf3b63     50.902500      -1.428889
# 2       61d375e793c6feb83e5eb3e2     53.563611       8.554722
# 3       61d38481b7b7526e1adf3d23     40.688333     -74.028611
# 4       61d37d0199db2ccf7339eee1      9.372370     -79.879790
# ...                          ...           ...            ...
# 136245  61d3802b29b60f6113c89f3d     13.073889     100.895278
# 136246  61d38285b7b7526e1adf3a84     24.525000      54.376111
# 136247                       NaN           NaN            NaN
# 136248  61d38528b7b7526e1adf3e6f     39.716667     -75.521667
# 136249  61d384b1b7b7526e1adf3d83     28.950556     -95.319167
#
# [136250 rows x 9 columns]

# %% [markdown]
# # Merging datasets

# %%
# Step 1: Convert 'time' column to datetime in vessel_data
vessel_data['time'] = pd.to_datetime(vessel_data['time'])

# Step 2: Get the latest vessel data for each vessel
latest_vessel_data = vessel_data.loc[vessel_data.groupby('vesselId')['time'].idxmax()]

# Select relevant columns from the latest vessel data
latest_vessel_data = latest_vessel_data[['vesselId', 'latitude', 'longitude', 'navstat', 'portId', 'sog']]

# Step 3: Merge with schedule data on 'vesselId'
combined_data = pd.merge(schedule_data, latest_vessel_data, on='vesselId', how='left')

# Step 4: Display the resulting combined data
display(combined_data.head())
# Out:
#                    vesselId            shippingLineId  \
# 0  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 1  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 2  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 3  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 4  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
#
#              shippingLineName                arrivalDate  \
# 0  Wallenius Wilhelmsen Ocean  2023-10-02 00:00:00+00:00
# 1  Wallenius Wilhelmsen Ocean  2023-10-27 00:00:00+00:00
# 2  Wallenius Wilhelmsen Ocean  2023-10-19 00:00:00+00:00
# 3  Wallenius Wilhelmsen Ocean  2023-10-09 00:00:00+00:00
# 4  Wallenius Wilhelmsen Ocean  2023-09-25 00:00:00+00:00
#
#                  sailingDate                           portName  \
# 0  2023-10-03 00:00:00+00:00                  Port of Brunswick
# 1  2023-10-27 00:00:00+00:00                Port of Southampton
# 2  2023-10-20 00:00:00+00:00                Port of Bremerhaven
# 3  2023-10-10 00:00:00+00:00                   Port of New York
# 4  2023-09-26 00:00:00+00:00  Manzanillo International Terminal
#
#                    portId_x  portLatitude  portLongitude  latitude  longitude  \
# 0  61d38499b7b7526e1adf3d54     31.140556     -81.496667   8.80907  -79.58758
# 1  61d3832bb7b7526e1adf3b63     50.902500      -1.428889   8.80907  -79.58758
# 2  61d375e793c6feb83e5eb3e2     53.563611       8.554722   8.80907  -79.58758
# 3  61d38481b7b7526e1adf3d23     40.688333     -74.028611   8.80907  -79.58758
# 4  61d37d0199db2ccf7339eee1      9.372370     -79.879790   8.80907  -79.58758
#
#    navstat                  portId_y  sog
# 0      0.0  61d37cff99db2ccf7339eedd  3.1
# 1      0.0  61d37cff99db2ccf7339eedd  3.1
# 2      0.0  61d37cff99db2ccf7339eedd  3.1
# 3      0.0  61d37cff99db2ccf7339eedd  3.1
# 4      0.0  61d37cff99db2ccf7339eedd  3.1

# %%
# Step 1: Merge the combined dataset with the ports data on 'portId'
combined_data = pd.merge(combined_data, ports_data[['portId', 'name', 'portLocation', 'longitude', 'latitude', 'countryName']], 
                          left_on='portId_x', right_on='portId', how='left')

# Step 2: Drop any redundant columns if necessary
# You can drop the original portId_x and keep the new portId from ports_data
combined_data.drop(columns=['portId_x'], inplace=True)

# Step 3: Display the updated combined dataset
display(combined_data)
# Out:
#                         vesselId            shippingLineId  \
# 0       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 1       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 2       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 3       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 4       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# ...                          ...                       ...
# 136245  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136246  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136247  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136248  61e9f3a9b937134a3c4bfe01  61a8e672f9cba188601e84ab
# 136249  61e9f3a9b937134a3c4bfe01  61a8e672f9cba188601e84ab
#
#                   shippingLineName                arrivalDate  \
# 0       Wallenius Wilhelmsen Ocean  2023-10-02 00:00:00+00:00
# 1       Wallenius Wilhelmsen Ocean  2023-10-27 00:00:00+00:00
# 2       Wallenius Wilhelmsen Ocean  2023-10-19 00:00:00+00:00
# 3       Wallenius Wilhelmsen Ocean  2023-10-09 00:00:00+00:00
# 4       Wallenius Wilhelmsen Ocean  2023-09-25 00:00:00+00:00
# ...                            ...                        ...
# 136245            Hoegh Autoliners  2023-12-03 23:00:00+00:00
# 136246            Hoegh Autoliners  2023-11-14 23:00:00+00:00
# 136247            Hoegh Autoliners  2023-11-15 23:00:00+00:00
# 136248            Hoegh Autoliners  2023-08-28 01:00:00+00:00
# 136249            Hoegh Autoliners  2023-08-20 04:30:00+00:00
#
#                       sailingDate                           portName  \
# 0       2023-10-03 00:00:00+00:00                  Port of Brunswick
# 1       2023-10-27 00:00:00+00:00                Port of Southampton
# 2       2023-10-20 00:00:00+00:00                Port of Bremerhaven
# 3       2023-10-10 00:00:00+00:00                   Port of New York
# 4       2023-09-26 00:00:00+00:00  Manzanillo International Terminal
# ...                           ...                                ...
# 136245  2023-12-03 23:00:00+00:00               Port of Laem Chabang
# 136246  2023-11-14 23:00:00+00:00                         Port Zayed
# 136247  2023-11-15 23:00:00+00:00                                NaN
# 136248  2023-08-30 17:00:00+00:00             The Port of Wilmington
# 136249  2023-08-23 04:30:00+00:00                      Port Freeport
#
#         portLatitude  portLongitude  latitude_x  longitude_x  navstat  \
# 0          31.140556     -81.496667     8.80907    -79.58758      0.0
# 1          50.902500      -1.428889     8.80907    -79.58758      0.0
# 2          53.563611       8.554722     8.80907    -79.58758      0.0
# 3          40.688333     -74.028611     8.80907    -79.58758      0.0
# 4           9.372370     -79.879790     8.80907    -79.58758      0.0
# ...              ...            ...         ...          ...      ...
# 136245     13.073889     100.895278    35.90857    141.00919      0.0
# 136246     24.525000      54.376111    35.90857    141.00919      0.0
# 136247           NaN            NaN    35.90857    141.00919      0.0
# 136248     39.716667     -75.521667         NaN          NaN      NaN
# 136249     28.950556     -95.319167         NaN          NaN      NaN
#
#                         portId_y   sog                    portId  \
# 0       61d37cff99db2ccf7339eedd   3.1  61d38499b7b7526e1adf3d54
# 1       61d37cff99db2ccf7339eedd   3.1  61d3832bb7b7526e1adf3b63
# 2       61d37cff99db2ccf7339eedd   3.1  61d375e793c6feb83e5eb3e2
# 3       61d37cff99db2ccf7339eedd   3.1  61d38481b7b7526e1adf3d23
# 4       61d37cff99db2ccf7339eedd   3.1  61d37d0199db2ccf7339eee1
# ...                          ...   ...                       ...
# 136245  61d379911366c3998241d850  13.5  61d3802b29b60f6113c89f3d
# 136246  61d379911366c3998241d850  13.5  61d38285b7b7526e1adf3a84
# 136247  61d379911366c3998241d850  13.5                       NaN
# 136248                       NaN   NaN  61d38528b7b7526e1adf3e6f
# 136249                       NaN   NaN  61d384b1b7b7526e1adf3d83
#
#                                      name  portLocation  longitude_y  \
# 0                       Port of Brunswick     Brunswick   -81.496667
# 1                     Port of Southampton   Southampton    -1.428889
# 2                     Port of Bremerhaven   Bremerhaven     8.554722
# 3                        Port of New York      New York   -74.028611
# 4       Manzanillo International Terminal         Colon   -79.879790
# ...                                   ...           ...          ...
# 136245               Port of Laem Chabang  Laem Chabang   100.895278
# 136246                         Port Zayed     Abu Dhabi    54.376111
# 136247                                NaN           NaN          NaN
# 136248             The Port of Wilmington    Wilmington   -75.521667
# 136249                      Port Freeport      Freeport   -95.319167
#
#         latitude_y           countryName
# 0        31.140556         United States
# 1        50.902500        United Kingdom
# 2        53.563611               Germany
# 3        40.688333         United States
# 4         9.372370                Panama
# ...            ...                   ...
# 136245   13.073889              Thailand
# 136246   24.525000  United Arab Emirates
# 136247         NaN                   NaN
# 136248   39.716667         United States
# 136249   28.950556         United States
#
# [136250 rows x 19 columns]

# %%
# Step 1: Merge the combined dataset with the vessels information on 'vesselId'
combined_data = pd.merge(combined_data, vessels_info[['vesselId', 'shippingLineId', 'CEU', 'DWT', 
                                                       'GT', 'vesselType', 'length', 'maxSpeed']], 
                          on='vesselId', how='left')

# Step 2: Drop any redundant columns if necessary
# For instance, if there are multiple columns for shippingLineId, you may want to drop duplicates.
# combined_data.drop(columns=['redundant_column'], inplace=True)  # Adjust based on actual redundancy

# Step 3: Display the updated combined dataset
display(combined_data.head())
# Out:
#                    vesselId          shippingLineId_x  \
# 0  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 1  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 2  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 3  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 4  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
#
#              shippingLineName                arrivalDate  \
# 0  Wallenius Wilhelmsen Ocean  2023-10-02 00:00:00+00:00
# 1  Wallenius Wilhelmsen Ocean  2023-10-27 00:00:00+00:00
# 2  Wallenius Wilhelmsen Ocean  2023-10-19 00:00:00+00:00
# 3  Wallenius Wilhelmsen Ocean  2023-10-09 00:00:00+00:00
# 4  Wallenius Wilhelmsen Ocean  2023-09-25 00:00:00+00:00
#
#                  sailingDate                           portName  portLatitude  \
# 0  2023-10-03 00:00:00+00:00                  Port of Brunswick     31.140556
# 1  2023-10-27 00:00:00+00:00                Port of Southampton     50.902500
# 2  2023-10-20 00:00:00+00:00                Port of Bremerhaven     53.563611
# 3  2023-10-10 00:00:00+00:00                   Port of New York     40.688333
# 4  2023-09-26 00:00:00+00:00  Manzanillo International Terminal      9.372370
#
#    portLongitude  latitude_x  longitude_x  ...  longitude_y latitude_y  \
# 0     -81.496667     8.80907    -79.58758  ...   -81.496667  31.140556
# 1      -1.428889     8.80907    -79.58758  ...    -1.428889  50.902500
# 2       8.554722     8.80907    -79.58758  ...     8.554722  53.563611
# 3     -74.028611     8.80907    -79.58758  ...   -74.028611  40.688333
# 4     -79.879790     8.80907    -79.58758  ...   -79.879790   9.372370
#
#       countryName          shippingLineId_y     CEU      DWT       GT  \
# 0   United States  61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0
# 1  United Kingdom  61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0
# 2         Germany  61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0
# 3   United States  61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0
# 4          Panama  61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0
#
#    vesselType length maxSpeed
# 0        83.0  231.0      NaN
# 1        83.0  231.0      NaN
# 2        83.0  231.0      NaN
# 3        83.0  231.0      NaN
# 4        83.0  231.0      NaN
#
# [5 rows x 26 columns]

# %%
print(combined_data)
# Out:
#                         vesselId          shippingLineId_x  \
# 0       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 1       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 2       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 3       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 4       61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# ...                          ...                       ...
# 136245  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136246  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136247  61e9f3abb937134a3c4bfe19  61a8e672f9cba188601e84ab
# 136248  61e9f3a9b937134a3c4bfe01  61a8e672f9cba188601e84ab
# 136249  61e9f3a9b937134a3c4bfe01  61a8e672f9cba188601e84ab
#
#                   shippingLineName                arrivalDate  \
# 0       Wallenius Wilhelmsen Ocean  2023-10-02 00:00:00+00:00
# 1       Wallenius Wilhelmsen Ocean  2023-10-27 00:00:00+00:00
# 2       Wallenius Wilhelmsen Ocean  2023-10-19 00:00:00+00:00
# 3       Wallenius Wilhelmsen Ocean  2023-10-09 00:00:00+00:00
# 4       Wallenius Wilhelmsen Ocean  2023-09-25 00:00:00+00:00
# ...                            ...                        ...
# 136245            Hoegh Autoliners  2023-12-03 23:00:00+00:00
# 136246            Hoegh Autoliners  2023-11-14 23:00:00+00:00
# 136247            Hoegh Autoliners  2023-11-15 23:00:00+00:00
# 136248            Hoegh Autoliners  2023-08-28 01:00:00+00:00
# 136249            Hoegh Autoliners  2023-08-20 04:30:00+00:00
#
#                       sailingDate                           portName  \
# 0       2023-10-03 00:00:00+00:00                  Port of Brunswick
# 1       2023-10-27 00:00:00+00:00                Port of Southampton
# 2       2023-10-20 00:00:00+00:00                Port of Bremerhaven
# 3       2023-10-10 00:00:00+00:00                   Port of New York
# 4       2023-09-26 00:00:00+00:00  Manzanillo International Terminal
# ...                           ...                                ...
# 136245  2023-12-03 23:00:00+00:00               Port of Laem Chabang
# 136246  2023-11-14 23:00:00+00:00                         Port Zayed
# 136247  2023-11-15 23:00:00+00:00                                NaN
# 136248  2023-08-30 17:00:00+00:00             The Port of Wilmington
# 136249  2023-08-23 04:30:00+00:00                      Port Freeport
#
#         portLatitude  portLongitude  latitude_x  longitude_x  ...  \
# 0          31.140556     -81.496667     8.80907    -79.58758  ...
# 1          50.902500      -1.428889     8.80907    -79.58758  ...
# 2          53.563611       8.554722     8.80907    -79.58758  ...
# 3          40.688333     -74.028611     8.80907    -79.58758  ...
# 4           9.372370     -79.879790     8.80907    -79.58758  ...
# ...              ...            ...         ...          ...  ...
# 136245     13.073889     100.895278    35.90857    141.00919  ...
# 136246     24.525000      54.376111    35.90857    141.00919  ...
# 136247           NaN            NaN    35.90857    141.00919  ...
# 136248     39.716667     -75.521667         NaN          NaN  ...
# 136249     28.950556     -95.319167         NaN          NaN  ...
#
#         longitude_y latitude_y           countryName  \
# 0        -81.496667  31.140556         United States
# 1         -1.428889  50.902500        United Kingdom
# 2          8.554722  53.563611               Germany
# 3        -74.028611  40.688333         United States
# 4        -79.879790   9.372370                Panama
# ...             ...        ...                   ...
# 136245   100.895278  13.073889              Thailand
# 136246    54.376111  24.525000  United Arab Emirates
# 136247          NaN        NaN                   NaN
# 136248   -75.521667  39.716667         United States
# 136249   -95.319167  28.950556         United States
#
#                 shippingLineId_y     CEU      DWT       GT  vesselType length  \
# 0       61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0        83.0  231.0
# 1       61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0        83.0  231.0
# 2       61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0        83.0  231.0
# 3       61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0        83.0  231.0
# 4       61a8e672f9cba188601e84ac  7934.0  31143.0  74258.0        83.0  231.0
# ...                          ...     ...      ...      ...         ...    ...
# 136245  61a8e672f9cba188601e84ab  7850.0  27178.0  68871.0        83.0  228.0
# 136246  61a8e672f9cba188601e84ab  7850.0  27178.0  68871.0        83.0  228.0
# 136247  61a8e672f9cba188601e84ab  7850.0  27178.0  68871.0        83.0  228.0
# 136248  61a8e672f9cba188601e84ab  8500.0  22088.0  76420.0        83.0  199.0
# 136249  61a8e672f9cba188601e84ab  8500.0  22088.0  76420.0        83.0  199.0
#
#        maxSpeed
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 136245      NaN
# 136246      NaN
# 136247      NaN
# 136248     19.0
# 136249     19.0
#
# [136250 rows x 26 columns]

# %%
# Check the data types of each column
print(combined_data.dtypes)
# Out:
# vesselId             object
# shippingLineId_x     object
# shippingLineName     object
# arrivalDate          object
# sailingDate          object
# portName             object
# portLatitude        float64
# portLongitude       float64
# latitude_x          float64
# longitude_x         float64
# navstat             float64
# portId_y             object
# sog                 float64
# portId               object
# name                 object
# portLocation         object
# longitude_y         float64
# latitude_y          float64
# countryName          object
# shippingLineId_y     object
# CEU                 float64
# DWT                 float64
# GT                  float64
# vesselType          float64
# length              float64
# maxSpeed            float64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
# Convert arrivalDate column to datetime
combined_data['arrivalDate'] = pd.to_datetime(combined_data['arrivalDate'])

# Create essential time-based features from the arrivalDate
combined_data['hour'] = combined_data['arrivalDate'].dt.hour
combined_data['day_of_week'] = combined_data['arrivalDate'].dt.dayofweek
combined_data['month'] = combined_data['arrivalDate'].dt.month

# Optional: You can also create features from sailingDate if relevant
combined_data['sailingDate'] = pd.to_datetime(combined_data['sailingDate'])
combined_data['sailing_hour'] = combined_data['sailingDate'].dt.hour
combined_data['sailing_day_of_week'] = combined_data['sailingDate'].dt.dayofweek
combined_data['sailing_month'] = combined_data['sailingDate'].dt.month

# %% [markdown]
# # Handle missing values

# %%
# Fill missing values only for numeric columns
numeric_cols = combined_data.select_dtypes(include=[np.number]).columns
combined_data[numeric_cols] = combined_data[numeric_cols].fillna(combined_data[numeric_cols].mean())

# Optionally, handle categorical columns separately
# For example, for categorical columns, you could fill with the mode
categorical_cols = combined_data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    combined_data[col].fillna(combined_data[col].mode()[0], inplace=True)

# %% [markdown]
# # Extended Feature Engineering

# %%
from geopy.distance import great_circle

# Create lag features
combined_data['prev_latitude'] = combined_data['latitude_x'].shift(1)
combined_data['prev_longitude'] = combined_data['longitude_x'].shift(1)

# Create time-based features
combined_data['hour'] = combined_data['arrivalDate'].dt.hour
combined_data['day_of_week'] = combined_data['arrivalDate'].dt.dayofweek
combined_data['month'] = combined_data['arrivalDate'].dt.month

# Distance to destination port
combined_data['distance_to_port'] = combined_data.apply(
    lambda row: great_circle((row['latitude_x'], row['longitude_x']), (row['portLatitude'], row['portLongitude'])).kilometers, axis=1
)

# One-hot encoding categorical features
combined_data = pd.get_dummies(combined_data, columns=['vesselType', 'shippingLineId_x', 'navstat'], drop_first=True)

# Handle any missing values created during feature engineering
combined_data.bfill(inplace=True)  # Use backward fill to handle NaN values

# %% [markdown]
# # Training

# %%
print(combined_data)
# Out:
#                         vesselId            shippingLineName  \
# 0       61e9f3b1b937134a3c4bfe53  Wallenius Wilhelmsen Ocean
# 1       61e9f3b1b937134a3c4bfe53  Wallenius Wilhelmsen Ocean
# 2       61e9f3b1b937134a3c4bfe53  Wallenius Wilhelmsen Ocean
# 3       61e9f3b1b937134a3c4bfe53  Wallenius Wilhelmsen Ocean
# 4       61e9f3b1b937134a3c4bfe53  Wallenius Wilhelmsen Ocean
# ...                          ...                         ...
# 136245  61e9f3abb937134a3c4bfe19            Hoegh Autoliners
# 136246  61e9f3abb937134a3c4bfe19            Hoegh Autoliners
# 136247  61e9f3abb937134a3c4bfe19            Hoegh Autoliners
# 136248  61e9f3a9b937134a3c4bfe01            Hoegh Autoliners
# 136249  61e9f3a9b937134a3c4bfe01            Hoegh Autoliners
#
#                      arrivalDate               sailingDate  \
# 0      2023-10-02 00:00:00+00:00 2023-10-03 00:00:00+00:00
# 1      2023-10-27 00:00:00+00:00 2023-10-27 00:00:00+00:00
# 2      2023-10-19 00:00:00+00:00 2023-10-20 00:00:00+00:00
# 3      2023-10-09 00:00:00+00:00 2023-10-10 00:00:00+00:00
# 4      2023-09-25 00:00:00+00:00 2023-09-26 00:00:00+00:00
# ...                          ...                       ...
# 136245 2023-12-03 23:00:00+00:00 2023-12-03 23:00:00+00:00
# 136246 2023-11-14 23:00:00+00:00 2023-11-14 23:00:00+00:00
# 136247 2023-11-15 23:00:00+00:00 2023-11-15 23:00:00+00:00
# 136248 2023-08-28 01:00:00+00:00 2023-08-30 17:00:00+00:00
# 136249 2023-08-20 04:30:00+00:00 2023-08-23 04:30:00+00:00
#
#                                  portName  portLatitude  portLongitude  \
# 0                       Port of Brunswick     31.140556     -81.496667
# 1                     Port of Southampton     50.902500      -1.428889
# 2                     Port of Bremerhaven     53.563611       8.554722
# 3                        Port of New York     40.688333     -74.028611
# 4       Manzanillo International Terminal      9.372370     -79.879790
# ...                                   ...           ...            ...
# 136245               Port of Laem Chabang     13.073889     100.895278
# 136246                         Port Zayed     24.525000      54.376111
# 136247                Port of Bremerhaven     28.021038       4.338822
# 136248             The Port of Wilmington     39.716667     -75.521667
# 136249                      Port Freeport     28.950556     -95.319167
#
#         latitude_x  longitude_x                  portId_y  ...  \
# 0         8.809070    -79.58758  61d37cff99db2ccf7339eedd  ...
# 1         8.809070    -79.58758  61d37cff99db2ccf7339eedd  ...
# 2         8.809070    -79.58758  61d37cff99db2ccf7339eedd  ...
# 3         8.809070    -79.58758  61d37cff99db2ccf7339eedd  ...
# 4         8.809070    -79.58758  61d37cff99db2ccf7339eedd  ...
# ...            ...          ...                       ...  ...
# 136245   35.908570    141.00919  61d379911366c3998241d850  ...
# 136246   35.908570    141.00919  61d379911366c3998241d850  ...
# 136247   35.908570    141.00919  61d379911366c3998241d850  ...
# 136248   21.080716     10.23397  61d375e793c6feb83e5eb3e2  ...
# 136249   21.080716     10.23397  61d375e793c6feb83e5eb3e2  ...
#
#         vesselType_83.0 shippingLineId_x_61a8e672f9cba188601e84ac  \
# 0                  True                                      True
# 1                  True                                      True
# 2                  True                                      True
# 3                  True                                      True
# 4                  True                                      True
# ...                 ...                                       ...
# 136245             True                                     False
# 136246             True                                     False
# 136247             True                                     False
# 136248             True                                     False
# 136249             True                                     False
#
#        shippingLineId_x_61a8e673f9cba188601e84ae  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 136245                                     False
# 136246                                     False
# 136247                                     False
# 136248                                     False
# 136249                                     False
#
#        shippingLineId_x_61a8e673f9cba188601e84b3  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 136245                                     False
# 136246                                     False
# 136247                                     False
# 136248                                     False
# 136249                                     False
#
#         shippingLineId_x_61be24564ea00ae59d0fe37f  navstat_0.6902065659892234  \
# 0                                           False                       False
# 1                                           False                       False
# 2                                           False                       False
# 3                                           False                       False
# 4                                           False                       False
# ...                                           ...                         ...
# 136245                                      False                       False
# 136246                                      False                       False
# 136247                                      False                       False
# 136248                                      False                        True
# 136249                                      False                        True
#
#        navstat_1.0 navstat_5.0  navstat_6.0  navstat_9.0
# 0            False       False        False        False
# 1            False       False        False        False
# 2            False       False        False        False
# 3            False       False        False        False
# 4            False       False        False        False
# ...            ...         ...          ...          ...
# 136245       False       False        False        False
# 136246       False       False        False        False
# 136247       False       False        False        False
# 136248       False       False        False        False
# 136249       False       False        False        False
#
# [136250 rows x 43 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score

X = combined_data[['hour', 'day_of_week', 'month', 'CEU', 'length', 'maxSpeed', 
                   'prev_latitude', 'prev_longitude', 'distance_to_port']]
y_latitude = combined_data['latitude_x']  # Target for latitude
y_longitude = combined_data['longitude_x']  # Target for longitude

X_train_lat, X_test_lat, y_train_lat, y_test_lat = train_test_split(X, y_latitude, test_size=0.2, random_state=42)

model_latitude = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1)
model_latitude.fit(X_train_lat, y_train_lat)

# Make predictions on the test set for latitude
y_pred_latitude = model_latitude.predict(X_test_lat)

# Evaluate latitude model
mse_latitude = mean_squared_error(y_test_lat, y_pred_latitude)
r2_latitude = r2_score(y_test_lat, y_pred_latitude)

print(f'Mean Squared Error (Latitude): {mse_latitude}')
print(f'R-squared (Latitude): {r2_latitude}')

# Repeat the same for longitude
X_train_lon, X_test_lon, y_train_lon, y_test_lon = train_test_split(X, y_longitude, test_size=0.2, random_state=42)

# Train an XGBoost model for longitude prediction
model_longitude = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1)
model_longitude.fit(X_train_lon, y_train_lon)

# Make predictions on the test set for longitude
y_pred_longitude = model_longitude.predict(X_test_lon)

# Evaluate longitude model
mse_longitude = mean_squared_error(y_test_lon, y_pred_longitude)
r2_longitude = r2_score(y_test_lon, y_pred_longitude)

print(f'Mean Squared Error (Longitude): {mse_longitude}')
print(f'R-squared (Longitude): {r2_longitude}')
# Out:
# Mean Squared Error (Latitude): 71.4361980061399
# R-squared (Latitude): 0.9046245958136965
# Mean Squared Error (Longitude): 625.3245552552899
# R-squared (Longitude): 0.8952908315874507

# %% [markdown]
# # Kaggle submission

# %%
# Load the ais_test.csv file (as done before)
ais_test = pd.read_csv('../ais_test.csv', sep=',')

# Convert 'time' column to datetime
ais_test['time'] = pd.to_datetime(ais_test['time'])

# Create time-based features (consistent with the training data)
ais_test['hour'] = ais_test['time'].dt.hour
ais_test['day_of_week'] = ais_test['time'].dt.dayofweek
ais_test['month'] = ais_test['time'].dt.month

# Select the features that are available in both the training and test sets
# Note: Features like 'prev_latitude' and 'prev_longitude' may not be in ais_test.csv; adjust accordingly.
X_test = ais_test[['hour', 'day_of_week', 'month']]  # Add any other valid test features used in training

# %%
# Make predictions on the test data (scaled or non-scaled based on your training setup)
latitude_predictions = model_latitude.predict(X_test)
longitude_predictions = model_longitude.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Make predictions on the test data (scaled or non-scaled based on your training setup)
# ----> 2 latitude_predictions = model_latitude.predict(X_test)
#       3 longitude_predictions = model_longitude.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['hour', 'day_of_week', 'month', 'CEU', 'length', 'maxSpeed', 'prev_latitude', 'prev_longitude', 'distance_to_port'] ['hour', 'day_of_week', 'month']
# expected prev_longitude, length, maxSpeed, CEU, distance_to_port, prev_latitude in input data

# %%
# Load the sample submission file
sample_submission = pd.read_csv('../ais_sample_submission.csv')

# Fill in the predicted latitude and longitude
sample_submission['latitude_predicted'] = latitude_predictions
sample_submission['longitude_predicted'] = longitude_predictions

# Save the submission file
sample_submission.to_csv('ais_filled_submission.csv', index=False)

# Display the first few rows to verify
print(sample_submission.head())
